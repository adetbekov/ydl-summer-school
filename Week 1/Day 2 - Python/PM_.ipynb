# %%
import matplotlib.pyplot as plt
import matplotlib 
import numpy as np
import math
# %matplotlib inline

# %%
x = np.linspace(0,math.pi*2,10)
y = np.sin(x)

# %%
plt.plot(x,y)
plt.show()

# %%
plt.plot(x,y,'g*-')

# %%
plt.plot(x, y, 'r')
plt.xlabel('X Axis Title Here')
plt.ylabel('Y Axis Title Here')
plt.title('String Title Here')
plt.show()

# %%
plt.subplot(2,2,1)
plt.plot(x, y, 'r--')
plt.subplot(2,2,2)
plt.plot(x, y, 'g*-')
plt.subplot(2,2,3)
plt.plot(x, y, 'b--')
plt.subplot(2,2,4)
plt.plot(x, y, 'y*-')

# %%
fig = plt.figure()
fig1 = fig.add_axes([0.1,0.1,0.8,0.8])
fig2 = fig.add_axes([0.7,0.5,0.5,0.3])
fig1.plot(x,y,'r')
fig2.plot(x,-y,'b')
fig2.set_ylabel("-sin")
fig.set_size_inches(3,3)
fig.savefig("twosines.png", dpi=600)

# %%
plt.plot(x,y, color=matplotlib.colors.rgb2hex((0,0,0)), alpha=0.5)
plt.plot(x+1,-y, color = "#8B008B")
plt.show()

# %%
plt.plot(x,y,color="purple",     lw = 2, ls="-", marker="o", markersize=7)
#plt.plot(x,y+0.2,color=[matplotlib.colors.rgb2hex((0,0,1/(i+1))) for i in range(50) ], lw = 3, ls="-", marker="*", markersize=7)
plt.plot(x,y+0.4,color="blue", lw = 1, ls="-", marker="v", markersize=7)
plt.plot(x,y+0.6,color="red", lw = 1, ls="-", marker="^", markersize=7)

# %%
#plt.plot(x,y+0.2,color=, lw = 3, ls="-", marker="*", markersize=7)
plt.scatter(x,y,c=[matplotlib.colors.rgb2hex((1-1/(i+1),0,1/(i+1))) for i in range(10)])

# %%
x = np.arange(50)
y = np.random.randint(1,50,50)

# %%
plt.scatter(x,y)

# %%
x = np.arange(-10,10)
y = x**2

# %%
plt.scatter(x,y)

# %%
plt.plot(x,y)

# %%
x = [int(math.sin(i)*20) for i in range(0,100)]
y = [int(math.cos(i)*20) for i in range(0,100)]
plt.plot(x,y)

# %%
x = np.arange(-10,10)
y = x**2
plt.bar(x,y)
# Out:
# <BarContainer object of 20 artists>

# %%
plt.pie([1,3,3,5], shadow=True, autopct="%1.1f%%")
plt.show()

# %%
x1 = [20,22]
y1 = [40,44]
plt.ylim([30,50])
plt.xlim([20,22])
plt.plot(x1,y1)
